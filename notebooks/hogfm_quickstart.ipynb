# %% [markdown]
# # HOGFM Quickstart
#
# Prepare a small promoter dataset, train a compact model, and query the API.

# %%
# !python scripts/prepare_dataset.py --examples 128 --length 128
# !python scripts/generate_scaling_report.py
